# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
#For standardizing features. We'll use the StandardScaler module.
from sklearn.preprocessing import StandardScaler
#Hierarchical clustering with the Sci Py library. We'll use the dendrogram and linkage modules.
from scipy.cluster.hierarchy import dendrogram, linkage
#Sk learn is one of the most widely used libraries for machine learning. We'll use the k-means module.
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
# We need to save the models, which we'll use in the next section. We'll use pickle for that.
import pickle

# %%
path = '/content/drive/MyDrive/Portfolio/projects/Customer Analytics/'

# %%
df_segmentation = pd.read_csv(path + 'data/segmentation data.csv')

# %%
df_segmentation.drop(columns=['ID'], inplace=True)

# %%
df_segmentation.head()
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1

# %%
df_segmentation.describe()
# Out:
#                Sex  Marital status  ...   Occupation  Settlement size
# count  2000.000000     2000.000000  ...  2000.000000      2000.000000
# mean      0.457000        0.496500  ...     0.810500         0.739000
# std       0.498272        0.500113  ...     0.638587         0.812533
# min       0.000000        0.000000  ...     0.000000         0.000000
# 25%       0.000000        0.000000  ...     0.000000         0.000000
# 50%       0.000000        0.000000  ...     1.000000         1.000000
# 75%       1.000000        1.000000  ...     1.000000         1.000000
# max       1.000000        1.000000  ...     2.000000         2.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# # Correlation Estimate

# %%
df_segmentation.corr()
# Out:
#                       Sex  Marital status  ...  Occupation  Settlement size
# Sex              1.000000        0.566511  ...   -0.202491        -0.300803
# Marital status   0.566511        1.000000  ...   -0.029490        -0.097041
# Age             -0.182885       -0.213178  ...    0.108388         0.119751
# Education        0.244838        0.374017  ...    0.064524         0.034732
# Income          -0.195146       -0.073528  ...    0.680357         0.490881
# Occupation      -0.202491       -0.029490  ...    1.000000         0.571795
# Settlement size -0.300803       -0.097041  ...    0.571795         1.000000
#
# [7 rows x 7 columns]

# %%
plt.figure(figsize= (12,9))
s = sns.heatmap(df_segmentation.corr(),
                annot =True,
                cmap ='RdBu',
                vmin = -1,
                vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 12)
s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 12)
plt.title('Correlation Heatmap')
plt.show()

# %%
# We'll plot the data. We create a 12 by 9 inches figure.
# We have 2000 data points, which we'll scatter acrros Age and Income, located on positions 2 and 4 in our data set. 
plt.figure(figsize = (12, 9))
plt.scatter(df_segmentation['Age'], df_segmentation['Income'])
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Visualization of raw data')
# Out:
# Text(0.5, 1.0, 'Visualization of raw data')

# %% [markdown]
# # Standardize

# %%
scaler = StandardScaler()
segmentation_std = scaler.fit_transform(df_segmentation)

# %% [markdown]
# # Hierarchical Clustering

# %%
hier_clust = linkage(segmentation_std, method = 'ward')

# %%
plt.figure(figsize = (12,9))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(hier_clust,
           truncate_mode = 'level', 
           p = 5, 
           show_leaf_counts = False, 
           no_labels = True)
plt.show()

# %% [markdown]
# # K-means Clustering

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(segmentation_std)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means Clustering')
plt.show()

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)

# %%
kmeans.fit(segmentation_std)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %% [markdown]
# ## Results

# %%
df_segm_kmeans = df_segmentation.copy()
df_segm_kmeans['Segment K-means'] = kmeans.labels_
df_segm_kmeans
# Out:
#       Sex  Marital status  Age  ...  Occupation  Settlement size  Segment K-means
# 0       0               0   67  ...           1                2                0
# 1       1               1   22  ...           1                2                3
# 2       0               0   49  ...           0                0                1
# 3       0               0   45  ...           1                1                2
# 4       0               0   53  ...           1                1                2
# ...   ...             ...  ...  ...         ...              ...              ...
# 1995    1               0   47  ...           0                0                1
# 1996    1               1   27  ...           1                0                3
# 1997    0               0   31  ...           0                0                1
# 1998    1               1   24  ...           0                0                3
# 1999    0               0   25  ...           0                0                1
#
# [2000 rows x 8 columns]

# %%
df_seg = df_segm_kmeans.replace({0:'well-off',
                         1:'fewer-opportunities',
                         2:'standard',
                         3:'career focused'})

# %%
# plot histogram for each feature based on cluster 
for i in df_segm_kmeans.columns[:7]:
  plt.figure(figsize = (30, 6))
  for j in range(4):
    plt.subplot(1, 5, j+1)
    cluster = df_segm_kmeans[df_segm_kmeans['Segment K-means'] == j]
    cluster[i].hist()
    plt.title('{}    \nCluster - {} '.format(i,j))
  
  plt.show()

# %%
df_segm_analysis = df_segm_kmeans.groupby(['Segment K-means']).mean()
df_segm_analysis
# Out:
#                       Sex  Marital status  ...  Occupation  Settlement size
# Segment K-means                            ...
# 0                0.501901        0.692015  ...    1.129278         1.110266
# 1                0.352814        0.019481  ...    0.329004         0.043290
# 2                0.029825        0.173684  ...    1.271930         1.522807
# 3                0.853901        0.997163  ...    0.634043         0.422695
#
# [4 rows x 7 columns]

# %%
# Compute the size and proportions of the four clusters
df_segm_analysis['N Obs'] = df_segm_kmeans[['Segment K-means','Sex']].groupby(['Segment K-means']).count()
df_segm_analysis['Prop Obs'] = df_segm_analysis['N Obs'] / df_segm_analysis['N Obs'].sum()

# %%
df_segm_analysis
# Out:
#                       Sex  Marital status  ...  N Obs  Prop Obs
# Segment K-means                            ...
# 0                0.501901        0.692015  ...    263    0.1315
# 1                0.352814        0.019481  ...    462    0.2310
# 2                0.029825        0.173684  ...    570    0.2850
# 3                0.853901        0.997163  ...    705    0.3525
#
# [4 rows x 9 columns]

# %%
df_segm_analysis.rename({0:'well-off',
                         1:'fewer-opportunities',
                         2:'career focused',
                         3:'standard'})
# Out:
#                           Sex  Marital status  ...  N Obs  Prop Obs
# Segment K-means                                ...
# well-off             0.501901        0.692015  ...    263    0.1315
# fewer-opportunities  0.352814        0.019481  ...    462    0.2310
# career focused       0.029825        0.173684  ...    570    0.2850
# standard             0.853901        0.997163  ...    705    0.3525
#
# [4 rows x 9 columns]

# %%
# Add the segment labels to our table
df_segm_kmeans['Labels'] = df_segm_kmeans['Segment K-means'].map({0:'well-off',
                         1:'fewer-opportunities',
                         2:'career focused',
                         3:'standard'})

# %%
x_axis = df_segm_kmeans['Age']
y_axis = df_segm_kmeans['Income']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_segm_kmeans['Labels'], palette = ['g', 'r', 'c', 'm'])
plt.title('Segmentation K-means')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # PCA

# %%
pca = PCA()

# %%
pca.fit(segmentation_std)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.35696328, 0.26250923, 0.18821114, 0.0755775 , 0.05716512,
#        0.03954794, 0.02002579])

# %%
# Determine transformed features
#
X_train_pca = pca.fit_transform(segmentation_std)
#
# Determine explained variance using explained_variance_ration_ attribute
#
exp_var_pca = pca.explained_variance_ratio_
#
# Cumulative sum of eigenvalues; This will be used to create step plot
# for visualizing the variance explained by each principal component.
#
cum_sum_eigenvalues = np.cumsum(exp_var_pca)
#
# Create the visualization plot
#
plt.bar(range(0,len(exp_var_pca)), exp_var_pca, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(0,len(cum_sum_eigenvalues)), cum_sum_eigenvalues, where='mid',label='Cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
# We choose three components. 3 or 4 seems the right choice according to the previous graph.
pca = PCA(n_components = 3)

# %%
#Fit the model the our data with the selected number of components. In our case three.
pca.fit(segmentation_std)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# # PCA Results

# %%
# Here we discucss the results from the PCA.
# The components attribute shows the loadings of each component on each of the seven original features.
# The loadings are the correlations between the components and the original features. 
pca.components_
# Out:
# array([[-0.31469524, -0.19170439,  0.32609979,  0.15684089,  0.52452463,
#          0.49205868,  0.46478852],
#        [ 0.45800608,  0.51263492,  0.31220793,  0.63980683,  0.12468314,
#          0.01465779, -0.06963165],
#        [-0.29301261, -0.44197739,  0.60954372,  0.27560461, -0.16566231,
#         -0.39550539, -0.29568503]])

# %%
df_pca_comp = pd.DataFrame(data = pca.components_,
                           columns = df_segmentation.columns.values,
                           index = ['Component 1', 'Component 2', 'Component 3'])
df_pca_comp
# Out:
#                   Sex  Marital status  ...  Occupation  Settlement size
# Component 1 -0.314695       -0.191704  ...    0.492059         0.464789
# Component 2  0.458006        0.512635  ...    0.014658        -0.069632
# Component 3 -0.293013       -0.441977  ...   -0.395505        -0.295685
#
# [3 rows x 7 columns]

# %%
# Heat Map for Principal Components against original features. Again we use the RdBu color scheme and set borders to -1 and 1.
sns.heatmap(df_pca_comp,
            vmin = -1, 
            vmax = 1,
            cmap = 'RdBu',
            annot = True)
plt.yticks([0, 1, 2], 
           ['Component 1', 'Component 2', 'Component 3'],
        #    rotation = 45,
           fontsize = 9)
# Out:
# ([<matplotlib.axis.YTick at 0x7fa115c76c10>,
#   <matplotlib.axis.YTick at 0x7fa119728250>,
#   <matplotlib.axis.YTick at 0x7fa115be3e50>],
#  [Text(0, 0.5, 'Component 1'),
#   Text(0, 1.5, 'Component 2'),
#   Text(0, 2.5, 'Component 3')])

# %% [markdown]
# 1.   Component 1 refers to career focus of individual
# 2.   Component 2 refers to education and lifestyle
# 3.   Component 3 refers to experience a person has no matter if it is work or life experience

# %%
pca.transform(segmentation_std)
# Out:
# array([[ 2.51474593,  0.83412239,  2.1748059 ],
#        [ 0.34493528,  0.59814564, -2.21160279],
#        [-0.65106267, -0.68009318,  2.2804186 ],
#        ...,
#        [-1.45229829, -2.23593665,  0.89657125],
#        [-2.24145254,  0.62710847, -0.53045631],
#        [-1.86688505, -2.45467234,  0.66262172]])

# %%
scores_pca = pca.transform(segmentation_std)

# %% [markdown]
# # K-means clustering with PCA

# %%
wcss = []
for i in range(1,11):
    kmeans_pca = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
plt.show()

# %%
# We have chosen four clusters, so we run K-means with number of clusters equals four. 
# Same initializer and random state as before.
kmeans_pca = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)

# %%
# We fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %% [markdown]
# # K-means clustering with PCA Results

# %%
# We create a new data frame with the original features and add the PCA scores and assigned clusters.
df_segm_pca_kmeans = pd.concat([df_segmentation.reset_index(drop = True), pd.DataFrame(scores_pca)], axis = 1)
df_segm_pca_kmeans.columns.values[-3: ] = ['Component 1', 'Component 2', 'Component 3']
# The last column we add contains the pca k-means clustering labels.
df_segm_pca_kmeans['Segment K-means PCA'] = kmeans_pca.labels_

# %%
df_segm_pca_kmeans
# Out:
#       Sex  Marital status  Age  ...  Component 2  Component 3  Segment K-means PCA
# 0       0               0   67  ...     0.834122     2.174806                    0
# 1       1               1   22  ...     0.598146    -2.211603                    2
# 2       0               0   49  ...    -0.680093     2.280419                    1
# 3       0               0   45  ...    -0.579927     0.730731                    3
# 4       0               0   53  ...    -0.440496     1.244909                    3
# ...   ...             ...  ...  ...          ...          ...                  ...
# 1995    1               0   47  ...     0.298330     1.438958                    1
# 1996    1               1   27  ...     0.794727    -1.079871                    2
# 1997    0               0   31  ...    -2.235937     0.896571                    1
# 1998    1               1   24  ...     0.627108    -0.530456                    2
# 1999    0               0   25  ...    -2.454672     0.662622                    1
#
# [2000 rows x 11 columns]

# %%
# We calculate the means by segments.
df_segm_pca_kmeans_freq = df_segm_pca_kmeans.groupby(['Segment K-means PCA']).mean()
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status  ...  Component 2  Component 3
# Segment K-means PCA                            ...
# 0                    0.503788        0.689394  ...     2.029427     0.841953
# 1                    0.305011        0.095861  ...    -0.904856     1.005493
# 2                    0.900576        0.963977  ...     0.705300    -0.776925
# 3                    0.027444        0.168096  ...    -1.046172    -0.248046
#
# [4 rows x 10 columns]

# %%
# Calculate the size of each cluster and its proportion to the entire data set.
df_segm_pca_kmeans_freq['N Obs'] = df_segm_pca_kmeans[['Segment K-means PCA','Sex']].groupby(['Segment K-means PCA']).count()
df_segm_pca_kmeans_freq['Prop Obs'] = df_segm_pca_kmeans_freq['N Obs'] / df_segm_pca_kmeans_freq['N Obs'].sum()
df_segm_pca_kmeans_freq = df_segm_pca_kmeans_freq.rename({0:'well-off',
                         1:'fewer-opportunities',
                         2:'standard',
                         3:'career focused'})
df_segm_pca_kmeans_freq = df_segm_pca_kmeans_freq.rename(columns={'Component 1': 'Career-Component',
                                                                  'Component 2': 'Education-Lifestyle-Component',
                                                                  'Component 3': 'Experience-Component'})
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status  ...  N Obs  Prop Obs
# Segment K-means PCA                            ...
# well-off             0.503788        0.689394  ...    264    0.1320
# fewer-opportunities  0.305011        0.095861  ...    459    0.2295
# standard             0.900576        0.963977  ...    694    0.3470
# career focused       0.027444        0.168096  ...    583    0.2915
#
# [4 rows x 12 columns]

# %%
df_segm_pca_kmeans_freq[['Career-Component','Education-Lifestyle-Component','Experience-Component']]
# Out:
#                      Career-Component  ...  Experience-Component
# Segment K-means PCA                    ...
# well-off                     1.697646  ...              0.841953
# fewer-opportunities         -1.047610  ...              1.005493
# standard                    -1.106034  ...             -0.776925
# career focused               1.372663  ...             -0.248046
#
# [4 rows x 3 columns]

# %%
df_segm_pca_kmeans['Legend'] = df_segm_pca_kmeans['Segment K-means PCA'].map({0:'well-off',
                         1:'fewer-opportunities',
                         2:'standard',
                         3:'career focused'})

# %%
# Plot data by PCA components. The Y axis is the first component, X axis is the second.
x_axis = df_segm_pca_kmeans['Component 2']
y_axis = df_segm_pca_kmeans['Component 1']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_segm_pca_kmeans['Legend'], palette = ['g', 'r', 'c', 'm'])
plt.title('Clusters by PCA Components')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Data Export

# %%
# We save the objects we'll need in the Purchase Analytics part of the course. We export them as pickle objects.
# We need the scaler, pca and kmeans_pca objects to preprocess and segment the purchase data set.
pickle.dump(scaler, open(path + 'models/scaler.pickle', 'wb'))

# %%
pickle.dump(pca, open(path +'models/pca.pickle', 'wb'))

# %%
pickle.dump(kmeans_pca, open(path + 'models/kmeans_pca.pickle', 'wb'))
